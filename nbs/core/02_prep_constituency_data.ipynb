# %% [markdown]
# # 02 Prep parliamentary constituency data
#
# > A first look at the ONS data on a parliamentary constituency level. This includes total population, age, ethnicity and educational attainment.

# %% [markdown]
# ---

# %%
#|default_exp core.01_prep_data

# %%
#|hide
import nbdev; nbdev.nbdev_export()

# %%
#|hide
from nbdev.showdoc import show_doc

# %%
#|export
import dementia_inequalities as proj
from dementia_inequalities import const, log, utils, tools
import adu_proj.utils as adutils

# %%
#|export
import numpy as np 
import pandas as pd
# Out:
# /var/folders/4n/x6w1yfcx01qbymrsfpz4ybq00000gn/T/ipykernel_3069/3424933337.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# Start by loading the datasets:
# * mid-2020 parliamentary constituency population estimates by age
# * 2021 census ethnicity data
# * 2021 census educational qualifications data.

# %%
#|export
df_pc_age = pd.read_excel(const.data_path+'/mid2020parliconsyoaestimatesage.xlsx', sheet_name='Mid-2020 Persons')
df_pc_eth = pd.read_excel(const.data_path+'/ethnicity_2021census.xlsx')
df_pc_educ = pd.read_excel(const.data_path+'/qualifications_2021census.xlsx')
# Out:
# /Users/bea/miniconda3/envs/adu_env_dementia_ineq/lib/python3.10/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
# Tidy table 
df_pc_age.columns = df_pc_age.iloc[3]
df_pc_age.drop(df_pc_age.index[0:4], inplace=True)

# Add columns for >65 age 
age_65_loc = df_pc_age.columns.get_loc(65.0)
df_pc_age['over_65'] = df_pc_age.iloc[:,age_65_loc:].sum(axis=1)
df_pc_age['over_65_pc'] = df_pc_age['over_65']/df_pc_age['All Ages']

# %%
df_pc_age.head()
# Out:
# 3   PCON11CD                  PCON11NM All Ages     0.0     1.0     2.0  \
# 4  E14000530                 Aldershot   105168  1313.0  1401.0  1436.0
# 5  E14000531       Aldridge-Brownhills    77683   783.0   789.0   840.0
# 6  E14000532  Altrincham and Sale West   102444   943.0  1058.0  1130.0
# 7  E14000533              Amber Valley    92277   815.0   902.0   932.0
# 8  E14000534   Arundel and South Downs   102673   789.0   779.0   903.0
#
# 3     3.0     4.0     5.0     6.0  ...   83.0   84.0   85.0   86.0   87.0  \
# 4  1294.0  1347.0  1491.0  1323.0  ...  449.0  362.0  317.0  322.0  230.0
# 5   784.0   822.0   908.0   897.0  ...  568.0  461.0  412.0  348.0  333.0
# 6  1198.0  1390.0  1287.0  1416.0  ...  511.0  455.0  436.0  376.0  346.0
# 7  1008.0   957.0   964.0   939.0  ...  466.0  409.0  350.0  327.0  318.0
# 8   938.0   984.0  1097.0  1052.0  ...  737.0  690.0  590.0  552.0  496.0
#
# 3   88.0   89.0   90+  over_65  over_65_pc
# 4  186.0  179.0   802  16472.0    0.156626
# 5  319.0  253.0   922  18114.0    0.233178
# 6  311.0  292.0  1252  19395.0    0.189323
# 7  237.0  191.0   897  20266.0    0.219621
# 8  436.0  427.0  1562  29079.0     0.28322
#
# [5 rows x 96 columns]

# %%
# pivot from long format to wide for education and ethnicity datasets 
df_pc_educ_wide = df_pc_educ[['RegNationName','ConstituencyName', 'groups', 'Con_pc']].pivot_table(index=['RegNationName','ConstituencyName'], columns='groups', values='Con_pc')
df_pc_eth_wide = df_pc_eth[['ConstituencyName', 'ethnic_groups', 'Con_pc']].pivot_table(index='ConstituencyName', columns='ethnic_groups', values='Con_pc')

# %%
df_pc_educ_wide.head()
# Out:
# groups                             1 or more GCSEs  2 or more A levels  \
# RegNationName ConstituencyName
# East Midlands Amber Valley                0.131008            0.183863
#               Ashfield                    0.139701            0.176188
#               Bassetlaw                   0.129686            0.173597
#               Bolsover                    0.133019            0.177657
#               Boston and Skegness         0.136154            0.145172
#
# groups                             Apprenticeship  \
# RegNationName ConstituencyName
# East Midlands Amber Valley               0.070313
#               Ashfield                   0.068853
#               Bassetlaw                  0.067468
#               Bolsover                   0.067650
#               Boston and Skegness        0.071770
#
# groups                             Higher education qualifications  \
# RegNationName ConstituencyName
# East Midlands Amber Valley                                0.243244
#               Ashfield                                    0.205517
#               Bassetlaw                                   0.251465
#               Bolsover                                    0.222011
#               Boston and Skegness                         0.182568
#
# groups                             No qualifications  Other qualifications
# RegNationName ConstituencyName
# East Midlands Amber Valley                  0.216873              0.023691
#               Ashfield                      0.244210              0.025830
#               Bassetlaw                     0.217066              0.031033
#               Bolsover                      0.239934              0.026709
#               Boston and Skegness           0.286914              0.041268

# %%
df_pc_eth_wide.head()
# Out:
# ethnic_groups              African  Any other ethnic group      Arab  \
# ConstituencyName
# Aberavon                  0.002926                0.003042  0.000750
# Aberconwy                 0.001253                0.002345  0.000895
# Aldershot                 0.014307                0.024408  0.001770
# Aldridge-Brownhills       0.007418                0.009324  0.000451
# Altrincham and Sale West  0.010701                0.013912  0.010959
#
# ethnic_groups             Bangladeshi  Caribbean   Chinese  \
# ConstituencyName
# Aberavon                     0.005795   0.001024  0.003431
# Aberconwy                    0.001253   0.000609  0.003168
# Aldershot                    0.002867   0.006237  0.005024
# Aldridge-Brownhills          0.001172   0.009156  0.003503
# Altrincham and Sale West     0.002398   0.004033  0.027615
#
# ethnic_groups             English, Welsh, Scottish, Northern Irish or British  \
# ConstituencyName
# Aberavon                                                           0.935000
# Aberconwy                                                          0.938102
# Aldershot                                                          0.722020
# Aldridge-Brownhills                                                0.864846
# Altrincham and Sale West                                           0.751504
#
# ethnic_groups             Gypsy or Irish Traveller    Indian     Irish  \
# ConstituencyName
# Aberavon                                  0.001989  0.005781  0.003373
# Aberconwy                                 0.000555  0.002452  0.007715
# Aldershot                                 0.001905  0.020625  0.006659
# Aldridge-Brownhills                       0.000721  0.043000  0.006619
# Altrincham and Sale West                  0.000109  0.044579  0.018806
#
# ethnic_groups             Other Asian  Other Black  \
# ConstituencyName
# Aberavon                     0.005709     0.000793
# Aberconwy                    0.003258     0.000519
# Aldershot                    0.099161     0.004080
# Aldridge-Brownhills          0.004636     0.002267
# Altrincham and Sale West     0.009641     0.001784
#
# ethnic_groups             Other Mixed or Multiple ethnic groups  Other White  \
# ConstituencyName
# Aberavon                                               0.002725     0.014646
# Aberconwy                                              0.002757     0.026259
# Aldershot                                              0.006471     0.052896
# Aldridge-Brownhills                                    0.003941     0.014243
# Altrincham and Sale West                               0.008075     0.034581
#
# ethnic_groups             Pakistani      Roma  White and Asian  \
# ConstituencyName
# Aberavon                   0.002465  0.000346         0.004022
# Aberconwy                  0.000859  0.000233         0.003938
# Aldershot                  0.011359  0.001024         0.008295
# Aldridge-Brownhills        0.009130  0.000193         0.006568
# Altrincham and Sale West   0.036582  0.000614         0.011454
#
# ethnic_groups             White and Black African  White and Black Caribbean
# ConstituencyName
# Aberavon                                 0.001658                   0.004527
# Aberconwy                                0.001539                   0.002291
# Aldershot                                0.004098                   0.006794
# Aldridge-Brownhills                      0.001365                   0.011449
# Altrincham and Sale West                 0.003934                   0.008720

# %% [markdown]
# Let's check the length of each dataframe. They should include all the English parliamentary constituencies (533) plus all the Welsh constituencies (40).

# %%
print(len(df_pc_eth_wide))
print(len(df_pc_educ_wide))
print(len(df_pc_age))
# Out:
# 573
# 573
# 573
